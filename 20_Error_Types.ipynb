# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-adel/Statistics_EDA/blob/main/20_Error_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Types of error

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Note :** when the H0 is true and the p-value fall in the rejection region, this reject the null hypothesis so max level for the Type I  error is equal the significance level (alpha)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **HOW we choose the the alpha and the error type ?**

# %% [markdown]
# # We first determine which case is risky for us and after that we can set the alpha

# %% [markdown]
# # **Trade-off between Type I and Type II errors**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Notice :** if the sample size increase ech ditribution will be narrow and the effect of the trade-off will decreased as the overlap areas decrease

# %% [markdown]
# #**EX :**  the guilty or innocent
# * **H0 : innocent**
# # so the risk here to say that the person guilty and actually he is innocent as this will kill him :) so we seeking to reduce the alpha as much as possible to avoid this error happen
