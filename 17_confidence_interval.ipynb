# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-adel/Statistics_EDA/blob/main/17_confidence_interval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **confidence interval (CI)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # if we suppose that the above chart is the sampling ditribution for each sample size >= 30 and what if we want to estimate the population mean So
#
#  * if we take a sample mean (point estimate) and we don't know how it's good relative to the population mean or how it estimate the population mean
#
#  * so instead of taking the point estimate we use the interval estimate and
#   because of the shape for the normal distribution
#
#   **EX :** if we take a sample mean and take with it 2 std we find that we confident 95.4% that the population mean fall within the range [x' +- z_score * std] and as we don't have the std of the population we take the std of the sample [x' +- z_score * s/sqrt(n)]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Note :** if we want to increase the precission or the confidence level we find that the range became wider and larger and this make the case worst as the sample mean that i may choose fall in far point from the population mean so i can instead increase the sample size that make the distribution narrow and most of the sample mean may i choose fall in range very close from population mean but take care about the size as it may cost alot
