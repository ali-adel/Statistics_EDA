# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-adel/Statistics_EDA/blob/main/14_inferential_%26_Sampling_techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inferential Statistics**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # We use it to estimate the population, because of taking a census from the population cost alot so we taking a sample from the population ,and inference the population parameter (usually sigma , mu) from the sample statistic (usually sigma , x')

# %% [markdown]
# # **Note**
#
#
# *   **to apply inferential statistics on a sample , it should be random sample (each point have the same probability to choose it in the sample) and not biased for any reason**

# %% [markdown]
# # **Sampling Techniques**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Non-Probabilistic Sampling**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1. Convenience Sampling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Judgmental(Purposive) Sampling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Quota Sampling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # and we have certain amount of individuals for each category so we can choose the amount for each category by Convenience or  Judgmental sampling

# %% [markdown]
# # 4. Snowball Sampling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Probabilistic(Random) Sampling**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1. Simple Random Sample(SRS)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1. Systematic Sampling

# %% [markdown]
# # Note: should bee carefull about cyclical patterns to avoid skewed data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1. Stratified Sampling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1. Cluster Sampling

# %% [markdown]
# ![image.png](data:image/png;base64,...)
