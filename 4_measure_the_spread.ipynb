# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-adel/EDA/blob/main/4_measure_the_spread.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/melb_data.csv')

# %% [markdown]
# #1.  Variance

# %% [markdown]
# #![Screenshot 2024-04-02 013231.png](data:image/png;base64,...)

# %% [markdown]
# # we use the variance to measure the spread of data and depending on it we can know more info about data like if it safe or not and etc (it calcultes the average squared distance between the points and the mean )
#
#
#
# *   the variance with mu -> for population
#
# *   the variance with x_dash -> for sample

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #2.  Standard deviation (std)

# %% [markdown]
# #so we use the variance to calculate the standard deviation of specifiec data and then use it as a measure unit for variation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # but as it depending also on the mean so it sensitive for outliers

# %% [markdown]
# with normal distribution

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #3.   5 number summary

# %% [markdown]
# # we use it when the data have outliers as it depends on the median and it doesn't affected with outliers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['Price'].describe() # q1 -> 25% / q2-> 50% (median) / q3-> 75%
# Out:
# count    1.358000e+04
# mean     1.075684e+06
# std      6.393107e+05
# min      8.500000e+04
# 25%      6.500000e+05
# 50%      9.030000e+05
# 75%      1.330000e+06
# max      9.000000e+06
# Name: Price, dtype: float64

# %% [markdown]
# # if data have outlier so if it is after the max value then it will be the max instead our max point and the same for the minimum one and it's shape depend on data shape

# %% [markdown]
# #   example

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.boxplot(data=df,x='Price') # so it have outliers after (1.5 IQR + q3) so depends on our problem we decide what should we do with it
# Out:
# <Axes: xlabel='Price'>

# %%
df['Type'].value_counts()
# Out:
# h    9449
# u    3017
# t    1114
# Name: Type, dtype: int64

# %%
sns.boxplot(data=df,x='Price',y='Type') # so it have outliers after (1.5 IQR + q3) so depend on our problem we decide what should we do with it
# Out:
# <Axes: xlabel='Price', ylabel='Type'>
